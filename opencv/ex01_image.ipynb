# %%
# !pip3 install opencv-python
# Out:
# ...
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.8 MB 1.9 MB/s eta 0:00:21
#     --------------------------------------- 0.8/38.8 MB 13.3 MB/s eta 0:00:03
#    --- ------------------------------------ 3.7/38.8 MB 33.3 MB/s eta 0:00:02
#    ------ --------------------------------- 6.1/38.8 MB 39.3 MB/s eta 0:00:01
#    ------------ --------------------------- 12.4/38.8 MB 73.1 MB/s eta 0:00:01
#    ------------------ --------------------- 17.6/38.8 MB 131.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 22.1/38.8 MB 93.9 MB/s eta 0:00:01
#    ------------------------ --------------- 23.9/38.8 MB 81.8 MB/s eta 0:00:01
#    --------------------------- ------------ 26.4/38.8 MB 73.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 29.0/38.8 MB 59.5 MB/s eta 0:00:01
#    -------------------------------- ------- 31.7/38.8 MB 54.4 MB/s eta 0:00:01
# ...

# %%
# opencv 설치 확인
import cv2

# 버전 확인
print(cv2.__version__)
# Out:
# 4.10.0

# %% [markdown]
# ## 이미지를 읽고 출력하기

# %% [markdown]
# ### 이미지를 읽고 새창에 출력하기
# - cv2.imread(파일명, 이미지 형식) : 이미지 파일을 읽기 위한 객체를 리턴
#     - 이미지 형식 : 컬러 (cv2.IMREAD_COLOR), 흑백(cv2.IMREAD_GRAYSCALE) 등
# - cv2.imshow(제목, 이미지 객체) : 이미지 출력
# - cv2.waitKey(0) : 키보드 입력을 기다리는 시간 설정 (0 : 계속 기다림)
#     - 1/1000초 단위
# - cv2.destroyAllWindows() : 생성한 윈도우를 모두 닫는다
#
# ![image.png](attachment:image.png)

# %%
# 실습 -> 무한 루프에 빠짐 -> py 파일에 옮겨서 불러오기
# import cv2

# image = cv2.imread('images/01_lenna.png')
# cv2.imshow('Lenna', image)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
# !python session_01/ex_01.py
# Out:
# python: can't open file 'c:\\Users\\SMHRD\\Desktop\\opencv\\session_01\\ex_01.py': [Errno 2] No such file or directory

# %% [markdown]
# ### matplotlib을 이용하여 이미지 출력하기
# - plt.xticks() : x축에 간격을 구분하기 위한 눈금을 표현
# - plt.yticks() : y축에 간격을 구분하기 위한 눈금을 표현
# - plt.imshow() : 현재 figure에서 이미지 출력 (없을 경우 새 figure 생성)
# - plt.show() : figure을 디스플레이 해줌(imshow()의 뒤에 오는 것은 가능, 반대는 불가능)
# - %matplotlib inline : 주피터 노트북에서 figure이 셀 바로 밑에 출력되도록 하는 백엔드 커맨드

# %%
# !pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/165.9 kB ? eta -:--:--
#      -------------------------------- ----- 143.4/165.9 kB 4.3 MB/s eta 0:00:01
#      -------------------------------------- 165.9/165.9 kB 5.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    - -------------------------------------- 0.4/8.0 MB 7.6 MB/s eta 0:00:01
#    --- ------------------------------------ 0.8/8.0 MB 8.3 MB/s eta 0:00:01
#    ------ --------------------------------- 1.3/8.0 MB 9.4 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.1/8.0 MB 11.1 MB/s eta 0:00:01
#    -------------- ------------------------- 2.8/8.0 MB 12.0 MB/s eta 0:00:01
#    -------------------- ------------------- 4.0/8.0 MB 14.3 MB/s eta 0:00:01
#    --------------------------- ------------ 5.5/8.0 MB 17.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.9/8.0 MB 19.2 MB/s eta 0:00:01
# ...

# %%
# 예제 1
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 2, 0.2)
plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='forestgreen', marker='*', markersize=9)
plt.xticks([0, 1, 2])
plt.yticks(np.arange(1,6))

plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

image = cv2.imread('images/01_lenna.png')
plt.imshow(image)
plt.show()

# %% [markdown]
# - OpenCV는 색상 공간을 BGR(Blue Green Red)을 사용
# - Python 이미지들은 RGB을 사용하므로 변환 필요
# - 따라서, OpenCV로 읽은 이미지를 Matplotlib으로 출력하려면 색상공간을 변환해야 함
#
# ![image.png](attachment:image.png)
#
# - cv2.cvtColor(img, 색상변환 옵션)
#     - 색상 변환 옵션 : cv2.COLOR_BGR2RGB, cv2.COLOR_RGB2GRAY, cv2.COLOR_RGB2HSV 등

# %%
# 실습

import matplotlib.pyplot as plt
# %matplotlib inline

image = cv2.imread('images/01_lenna.png')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)
plt.show()

# %% [markdown]
# ### 직접 Red 채널과 Blue 채널을 바꾸기
# - b, g, r = cv2.split(img) : img 파일을 b, g, r로 분리
# - cv2.merge([r, g, b]) : b, r을 바꿔서 Merge

# %%
import matplotlib.pyplot as plt
image = cv2.imread('images/01_lenna.png')
b, g, r = cv2.split(image)
new_img = cv2.merge([r, g, b])
plt.imshow(new_img)
plt.show()

# %% [markdown]
# ### Gray와 Binary(이진화) 이미지
# - Binary(이진화) 이미지 : 0과 1로만 이루어진 이미지
# - 시각은 색상 정보에 대해 잘못된 정보를 보내주는 경우가 많음
#     - 밤에 색상을 볼 때 정확한 색상을 보여주지 못함 - 명도(검정색이 섞이는 것)
#     - 색상에 빛을 강하게 비추는 경우 정확한 색상을 보여주지 못함 - 채도(흰색이 섞이는 것)
# - 컬러는 너무 많은 정보를 가지고 있기 때문에 연산량이 많음
#     - 실시간 처리가 어려움
#     - 따라서 gray 이미지나 binary 이미지로 변환해서 처리하는 것이 일반적
#
# - gray 이미지 : 0-255로 된 픽셀로만 구성된 흑백 이미지
# - binary(이진) 이미지 : 0(검정색)과 255(흰색)으로만 구성된 이미지 (마스크 패턴, 필터링)
#
# - 컬러 → gray 이미지 변환 방법 2가지
#     - imread()로 이미지를 읽을 때 변환해서 읽는 방법
#         - img = cv2.imread(파일명, cv2.IMREAD_GRAYSCALE)
#     - 컬러 이미지로 읽어서 cvtColor() 변환하는 방법 → 컬러 이미지가 필요한 경우 (출력)
#         - img_gray = cv2.cvtColor(이미지 객체, cv2.COLOR_BGR2GRAY)
#
# - matplotlib 라이브러리의 colormap
#     - 기본값 : viridis \
#     \
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Colormap 살펴보기

# %%
# 예제 1
import numpy as np
from matplotlib import pyplot as plt 

Z = np.array([[10,0,0],[0,10,0],[0,0,10]])
print(Z)

plt.imshow(Z)
plt.show()
# Out:
# [[10  0  0]
#  [ 0 10  0]
#  [ 0  0 10]]

# %%
# 예제 2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm

Z = np.array([[20,5,2],[2,20,3],[11,2,20]])
plt.imshow(Z, cmap = cm.gray)
plt.show()

# %%
# 실습
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm

Z = np.array([[20,5,2],[2,20,3],[11,2,20]])
plt.imshow(Z, cmap = cm.inferno)
plt.show()

# %% [markdown]
# ### gray 이미지 만들기

# %% [markdown]
# ##### imread()를 사용해서 gray 이미지로 변환해서 읽는 방법

# %%
# option => cv2.IMREAD_GRAYSCALE

import cv2

image = cv2.imread('images/01_lenna.png', cv2.IMREAD_GRAYSCALE)
cv2.imshow('Gray Lenna', image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ##### 컬러 이미지로 읽어서 gray 이미지로 변환하는 방법

# %%
import cv2

image = cv2.imread('images/01_lenna.png', cv2.IMREAD_COLOR)
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2.imshow('Gray Lenna', image_gray)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### 이진(Binary) 이미지 만들기
# - 이진 이미지는 픽셀값이 0과 1(255)로만 구성
# - 이진 이미지의 필요 : 배경과 객체의 구분, 관심 영역과 비관심 영역의 구분, 마스크 생성 등
# - -, thr = cv2.threshold(img, threshold_value, value, flag)
#     - img : Grayscale 이미지
#     - threshold_value : 픽셀 문턱값 (0과 1로 나누기 위한 기준값)
#     - value : 문턱값보다 클 때 적용되는 값
#     - flag : 문턱값 적용 방법
# - flag : 문턱값 적용 방법
#     - cv2.THRESH_BINARY : 픽셀값이 문턱값보다 크면 value, 아니면 0을 할당
#     - cv2.THRESH_BINARY_INV : 픽셀값이 문턱값보다 크면 0, 아니면 value를 할당
#     - cv2.THRESH_TRUNC : 픽셀값이 문턱값보다 크면 문턱값, 아니면 픽셀값을 그대로 할당
#     - cv2.THRESH_TOZERO : 픽셀값이 문턱값보다 크면 픽셀값, 아니면 0을 할당
#     - cv2.THRESH_TOZERO_INV : 픽셀값이 문턱값보다 크면 0, 아니면 픽셀값을 할당

# %%
import cv2

image = cv2.imread('images/01_lenna.png', cv2.IMREAD_GRAYSCALE)
retval, thresholded_image = cv2.threshold(image, 127, 255, cv2. THRESH_BINARY)
# retval -> 사용된 문턱값
# thresholded_image -> 이진화된 결과 이미지

cv2.imshow('Thresholded Image', thresholded_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
